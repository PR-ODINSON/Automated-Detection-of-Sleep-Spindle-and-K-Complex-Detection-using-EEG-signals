# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Path to folder containing the Excel files
folder_path = "D:/OneDrive_2024-12-27/Segmented by seperating spindles/Balanced_segmented"

# Load and combine data from all Excel files
all_data = []
all_labels = []
for file in os.listdir(folder_path):
    if file.endswith(".xlsx"):
        file_path = os.path.join(folder_path, file)
        df = pd.read_excel(file_path)
        data = df.iloc[:, :-1].values  # Features (all columns except last)
        labels = df.iloc[:, -1].values  # Labels (last column)
        all_data.append(data)
        all_labels.append(labels)

# Combine all files into a single dataset
all_data = np.vstack(all_data)
all_labels = np.hstack(all_labels)

# Normalize the data
all_data = (all_data - np.min(all_data)) / (np.max(all_data) - np.min(all_data))

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(all_data, all_labels, test_size=0.2, random_state=42, stratify=all_labels)

# Reshape data for 1D CNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Convert labels to categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Build the 1D CNN model
model = Sequential([
    Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
    MaxPooling1D(pool_size=2),
    Dropout(0.2),
    Conv1D(filters=64, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),
    Dropout(0.2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')  # Output layer with 2 classes
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=1)

# Evaluate the model
eval_metrics = model.evaluate(X_test, y_test, verbose=0)
print("\nModel Evaluation:")
print(f"Loss: {eval_metrics[0]:.4f}, Accuracy: {eval_metrics[1]:.4f}")

# Predict and print the confusion matrix
y_pred = np.argmax(model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)

print("\nConfusion Matrix:")
print(confusion_matrix(y_true, y_pred))

print("\nClassification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Epoch 1/20
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.5093 - loss: 0.6918 - val_accuracy: 0.8681 - val_loss: 0.3326
# Epoch 2/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8860 - loss: 0.3054 - val_accuracy: 0.9158 - val_loss: 0.2367
# Epoch 3/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9093 - loss: 0.2529 - val_accuracy: 0.9167 - val_loss: 0.2310
# Epoch 4/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9120 - loss: 0.2331 - val_accuracy: 0.9319 - val_loss: 0.1912
# Epoch 5/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9244 - loss: 0.2091 - val_accuracy: 0.9341 - val_loss: 0.1835
# Epoch 6/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9298 - loss: 0.1917 - val_accuracy: 0.9435 - val_loss: 0.1589
# Epoch 7/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9365 - loss: 0.1740 - val_accuracy: 0.9428 - val_loss: 0.1542
# Epoch 8/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9374 - loss: 0.1704 - val_accuracy: 0.9546 - val_loss: 0.1345
# Epoch 9/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9424 - loss: 0.1596 - val_accuracy: 0.9536 - val_loss: 0.1402
# Epoch 10/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9455 - loss: 0.1574 - val_accuracy: 0.9507 - val_loss: 0.1418
# Epoch 11/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9463 - loss: 0.1572 - val_accuracy: 0.9583 - val_loss: 0.1274
# Epoch 12/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9510 - loss: 0.1434 - val_accuracy: 0.9621 - val_loss: 0.1169
# Epoch 13/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9511 - loss: 0.1406 - val_accuracy: 0.9665 - val_loss: 0.1115
# Epoch 14/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9566 - loss: 0.1247 - val_accuracy: 0.9599 - val_loss: 0.1172
# Epoch 15/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9565 - loss: 0.1267 - val_accuracy: 0.9587 - val_loss: 0.1132
# Epoch 16/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9559 - loss: 0.1268 - val_accuracy: 0.9676 - val_loss: 0.1044
# Epoch 17/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9591 - loss: 0.1228 - val_accuracy: 0.9580 - val_loss: 0.1195
# Epoch 18/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9589 - loss: 0.1163 - val_accuracy: 0.9622 - val_loss: 0.1063
# Epoch 19/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9611 - loss: 0.1130 - val_accuracy: 0.9651 - val_loss: 0.0994
# Epoch 20/20
# 706/706 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9641 - loss: 0.1128 - val_accuracy: 0.9686 - val_loss: 0.0947
#
# Model Evaluation:
# Loss: 0.0938, Accuracy: 0.9670
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Confusion Matrix:
# [[3313  212]
#  [  21 3507]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.97      3525
#            1       0.94      0.99      0.97      3528
#
#     accuracy                           0.97      7053
#    macro avg       0.97      0.97      0.97      7053
# weighted avg       0.97      0.97      0.97      7053
